# %%
# -*- coding: utf-8 -*-

import urllib.request

import os, sys, time, re

emoji_pattern = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           "]+", flags=re.UNICODE)

string = " "

#n = int(input("enter number of pages: "))

n = 2 #change this number for number of pages

for i in range(1,int(n)):
    wiki = "https://www.amazon.in/Mi-Max-Black-64-GB/product-reviews/B073VLGL5Y/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews"
    #wiki = "https://www.amazon.in/Fogg-Analog-White-Watch-2038-WH/dp/B076F947LW/ref=pd_rhf_cr_s_cp_0_3?_encoding=UTF8&pd_rd_i=B076F947LW&pd_rd_r=ZDRR09RV7C6HY3SVBFQA&pd_rd_w=qBlLv&pd_rd_wg=D95sJ&psc=1&refRID=ZDRR09RV7C6HY3SVBFQA"
    #wiki = "https://www.amazon.in/MTT-Premium-Cover-Lenovo-Black/product-reviews/B076DHC9NW/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews"
    #wiki = "https://www.amazon.in/Fogg-Analog-Blue-Watch-2038-BL/product-reviews/B075RBD78J/ref=cm_cr_getr_d_paging_btm_1?ie=UTF8&reviewerType=all_reviews&pageNumber=" + str(i)   
    page = urllib.request.urlopen(wiki) 

    from bs4 import BeautifulSoup

    soup = BeautifulSoup(page, "lxml")

    elements = soup.find_all("span", class_="a-size-based review-text".split())

    #print("\n".join("{} {}".format(el['class'], el.get_text()) for el in elements))
    
    for el in elements:
        #print(el.get_text()),
        strr = emoji_pattern.sub(r'', el.get_text())
        string = string + strr + "\n"
        print(strr)
        print("\n"),
        print("\n"),
    
    time.sleep(2)
    
    #if i%20 == 0:
        #time.sleep(10)

#string = emoji_pattern.sub(r'', string)

#f = open('C:\Rahul\college work\FYP\helloworld15.txt','w')
#f.write(string)
#f.close()
# Out:
# Don't think too much to buy this phoneIt is the best phone in this price segment...Then also it is good enough to compare with any other high range phonesNo other Mobile companies will offer u this much hardware and specifications in this price..... Snapdragon 625 2ghz with sony 12mp with 5300 mah reversible charging support, gorilla glass protection and 6.44inch good colour productive screen and much more..... The best thing is u can use it easily 1.5 days with very heavy usage.....And those who r complaining about the camera.... Just set the cameras in mannual mode and take pictures..... I have attached some samples of rear camera and front camera pics.... Just see that pics.... And the pics are not taken in sunlight.....all the pics are taken in cloudy weatherWhile recording Videos turn off the auto focus option and  use tap to focus to make qud quality videosand yes its support quick charge 3.0 which can charge ur mob from 0 to 100 in just 2hrAnd there is no heating issue for nor
# ...

# %%
###############  Product page to review page parsing  ###############
product 1:
url_1 = "https://www.amazon.in/Mi-Max-Black-64-GB/dp/B073VLGL5Y/ref=cm_cr_arp_d_product_top?ie=UTF8"
url_2 = "https://www.amazon.in/Mi-Max-Black-64-GB/product-reviews/B073VLGL5Y/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews"

product 2:
url_1 = ""
url_2 = ""
