# %%
########################## Naukri

import requests
import bs4
from bs4 import BeautifulSoup
import pandas as pd
import time

URL = "https://www.naukri.com/data-scientist-jobs-in-mumbai"
#conducting a request of the stated URL above:
page = requests.get(URL)
#specifying a desired format of “page” using the html parser - this allows python to read the various components of the page, rather than treating it as one long string.
soup = BeautifulSoup(page.text, "html.parser")
#printing soup in a more structured tree format that makes for easier reading
print(soup.prettify())
# Out:
# <!DOCTYPE HTML>
# <html class="srpPage">
#  <head>
#   <link href="https://www.naukri.com/data-scientist-jobs-in-mumbai" rel="canonical"/>
#   <meta charset="utf-8"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <link href="https://www.naukri.com/notifymanifest.json" rel="manifest"/>
#   <title>
#    Data Scientist Jobs in Mumbai - Data Scientist Openings in Mumbai - Naukri.com
#   </title>
#   <meta content="Apply to 342 Data Scientist Jobs in Mumbai on Naukri.com, India's No.1 Job Portal. Explore Data Scientist job openings in Mumbai Now!" name="description"/>
#   <meta content="2018 Naukri.com" name="copyright"/>
#   <meta content="EN" name="content-language"/>
#   <meta content="www.naukri.com" name="author"/>
#   <meta content="document" name="resource-type"/>
#   <meta content="GLOBAL" name="distribution"/>
#   <meta content="1 day" name="revisit-after"/>
#   <meta content="general" name="rating"/>
#   <meta content="no-cache" name="pragma"/>
#   <meta content="Jobs &amp; Career: Job Search, Apply Jobs, Post Jobs" name="classification"/>
#   <meta content="ALL" name="robots"/>
#   <link href="https://www.naukri.com/data-scientist-jobs-in-mumbai-2" rel="next"/>
#   <link href="android-app://naukriApp.appModules.login/https/www.naukri.com/data-scientist-jobs-in-mumbai" rel="alternate"/>
#   <script src="//static.naukimg.com/s/0/0/j/nLoggerJB_v1.9.min.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    nLogger.init({"tag":"revamped_srp","nLogger":{"beaconUrl":"https:\/\/lg.naukri.com\/nLogger\/errLogger.php"},"boomerang":{"logBW":false,"beaconUrl":"https:\/\/lg.naukri.com\/nLogger\/boomLogger.php","imageURL":"\/\/static.naukimg.com\/s\/0\/0\/i\/"},"appId":109,"userIP":"1729348796"});
#   </script>
#   <script>
#    (function() { var queuedSuperProps = []; var queuedEvents = []; window.ub = { track: function(eventName, eventProps) { queuedEvents.push([eventName, eventProps]) }, register: function(properties) { queuedSuperProps.push(properties); } };
#             var script = document.createElement("script"); script.async = true; script.src = "//static.naukimg.com/s/0/1/j/ub_v1.min.js";script.onload = function() { ub.init({
#                     beaconUrl : "https://logs.naukri.com/uba", queuedEvents:queuedEvents, queuedSuperProps:queuedSuperProps,  tenantId:'1' , autoTrack:false, blackList:
#                 []
#             }); };document.head.appendChild(script);}()); ub.register({ appId:109, pageName: "jobsearch",  tenantId:'1' , });
#   </script>
#   <link href="https://static.naukimg.com/s/4/101/c/common_v62.min.css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://static.naukimg.com/s/4/109/c/srpStyle_v26.min.css" media="all" rel="stylesheet" type="text/css"/>
#   <script async="" src="//ht-nkr.native.andbeyond.media/js/abm_naukri.com.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    var pageId = 20151204
#   </script>
#   <script type="text/javascript">
#    var marketingUrl = "";
#   </script>
#   <script data-cfasync="false" type="text/javascript">
#    (function(w, d) { var s = d.createElement('script'); s.src = '//delivery.adrecover.com/14198/adRecover.js'; s.type = 'text/javascript'; s.async = true; (d.getElementsByTagName('head')[0] || d.getElementsByTagName('body')[0]).appendChild(s); })(window, document);
#   </script>
#   <script async="" src="//cdn.automatad.com/axt/ad_axt_naukri.min.js" type="text/javascript">
#   </script>
#   <script>
#    var global={layers:{}};
#              global.premium={"mbaUrl":'https://www.naukri.com/premium-jobs-for-iim-mba-graduates', "enggUrl":"https://www.naukri.com/premium-jobs-for-iit-engineering-graduates"};
#              global.searchUrl='https://www.naukri.com';
#              global.username='';
#              global.isRemembered='';
#              global.resid = '';
#              global.mynaukrihomeUrl='https://my.naukri.com/HomePage/view';
#              global.mynaukricompleteprofileurl='https://my.naukri.com/CompleteProfile/editPage1';
#              var premCookieDomainName =  '.naukri.com' ;
#              var trackImpression = {};
#                         trackImpression['ambitionBoxAd'] = "SRP|Ambitionbox_bellyad_LO";
#   </script>
#   <script>
#    var fbCategory =  'non premium' ;
# 	var fbSource = 'other';
#   </script>
#   <noscript>
#    <img height="1" src="https://www.facebook.com/tr?id=282225171957352&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
#   </noscript>
#  </head>
#  <body class="_srpPage ">
#   <div class="overlay">
#    <div class="nLoader45">
#    </div>
#   </div>
#   <!--[if lte IE 9]>
#
# <div class="msgBar red wrap"> <div class="cnt">We support Internet Explorer version 10 and above. You are using an <b>Older</b>  version. Kindly<a target="_blank" href="http://windows.microsoft.com/en-IN/internet-explorer/download-ie"><b> Upgrade your browser</b></a></div></div>
#
# <![endif]-->
#   <div class="headGNBWrap">
#    <div class="headGNB cloneCont wrap" itemscope="" itemtype="https://schema.org/Organization">
#     <a class="nLogo fl" href="https://www.naukri.com" itemprop="url">
#      <img alt="Naukri.com, India’s No.1 Job Site" itemprop="logo" src="https://static.naukimg.com/s/4/100/i/naukri_Logo.png"/>
#     </a>
#     <ul class="midSec menu">
#      <li class="mActive">
#       <a href="https://www.naukri.com/browse-jobs" target="_blank" title="Search Jobs">
#        <span class="topIcon jobs">
#        </span>
#        <div class="mTxt">
#         Jobs
#        </div>
#       </a>
#       <div class="subMenu c2">
#        <ul>
#         <li>
#          <a href="https://www.naukri.com/browse-jobs" target="_blank" title="Browse All Jobs">
#           Browse All Jobs
#          </a>
#         </li>
#         <li>
#          <a href="https://www.naukri.com/jobs-by-location" target="_blank" title="Jobs by Location">
#           Jobs by Location
#          </a>
#         </li>
#         <li>
#          <a href="https://www.naukri.com/top-skill-jobs" target="_blank" title="Jobs by Skill">
#           Jobs by Skill
#          </a>
#         </li>
#         <li>
#          <a href="https://www.naukri.com/top-jobs-by-designations" target="_blank" title="Jobs by Designation">
#           Jobs by Designation
#          </a>
#         </li>
#         <li>
#          <a class="" data-ga-track="CreateCJA_Desktop|CreateCJA_Desktop_GNB_HP" href="https://www.naukri.com/free-job-alerts" target="_blank" title="Create Free Job Alert">
#           Create Free Job Alert
#          </a>
#         </li>
#        </ul>
#        <ul>
#         <li>
#          <a href="https://www.naukri.com/top-company-jobs" target="_blank" title="Jobs by Company">
#           Jobs by Company
#          </a>
#         </li>
#         <li>
#          <a href="https://www.naukri.com/jobs-by-category" target="_blank" title="Jobs by Category">
#           Jobs by Category
#          </a>
#         </li>
#         <li>
#          <a class="target_advanceSeachLayer" data-domain="https://www.naukri.com/" href="https://www.naukri.com/advanced-search" target="_blank" title="Advanced Search">
#           Advanced Search
#          </a>
#         </li>
#         <li>
#          <a href="https://www.naukri.com/tieups/tieups.php?othersrcp=5424&amp;id=" title="Post your Resume">
#           Post your Resume
#          </a>
#         </li>
#        </ul>
#       </div>
#      </li>
#      <li class="''">
#       <a href="https://www.naukri.com/recruiters" target="_blank" title="Search Recruiters">
#        <span class="topIcon jobs Recr">
#        </span>
#        <div class="mTxt">
#         Recruiters
#        </div>
#       </a>
#       <div class="subMenu">
#        <ul>
#         <li>
#          <a href="https://www.naukri.com/recruiters/browse-all-recruiters" target="_blank" title="Browse All Recruiters">
#           Browse All Recruiters
#          </a>
#         </li>
#         <li>
#          <a href="https://naukrirecruiter.naukri.com?src=128" target="_blank" title="Go to NaukriRecruiter">
#           Go to NaukriRecruiter
#          </a>
#         </li>
#        </ul>
#       </div>
#      </li>
#      <li class="''">
#       <a href="https://www.naukri.com/top-company-jobs" target="_blank" title="Jobs Posted By Top Companies">
#        <span class="topIcon jobs Comp">
#        </span>
#        <div class="mTxt">
#         Companies
#        </div>
#       </a>
#       <div class="subMenu">
#        <ul>
#         <li>
#          <a href="https://www.naukri.com/top-company-jobs" target="_blank" title="Browse All Companies">
#           Browse All Companies
#          </a>
#         </li>
#         <li>
#          <a href="http://ambitionbox.com/interviews?utm_source=naukri&amp;utm_medium=gnb" target="_blank" title="Interview Questions">
#           Interview Questions
#          </a>
#         </li>
#         <li>
#          <a href="http://ambitionbox.com/companies?utm_source=naukri&amp;utm_medium=gnb" rel="noindex nofollow" target="_blank" title="About Companies">
#           About Companies
#          </a>
#         </li>
#         <li>
#          <a href="http://ambitionbox.com/contribute?review_name=CompanyReview&amp;utm_source=naukri&amp;utm_medium=gnb" rel="noindex nofollow" target="_blank" title="Write Company Review">
#           Write Company Review
#          </a>
#         </li>
#         <li>
#          <a href="http://ambitionbox.com/contribute?review_name=InterviewAdvice&amp;utm_source=naukri&amp;utm_medium=gnb" target="_blank" title="Write Interview Advice">
#           Write Interview Advice
#          </a>
#         </li>
#        </ul>
#       </div>
#      </li>
#      <li class="''">
#       <a href="https://resume.naukri.com/resume-services?fftid=100001&amp;id=" target="_blank" title="Naukri FastForward- Resume Services">
#        <span class="topIcon jobs Serv">
#        </span>
#        <div class="mTxt">
#         Services
#        </div>
#       </a>
#       <div class="subMenu c3">
#        <ul class="group">
#         <li class="header1">
#          <a title="Resume Writing">
#           Resume Writing
#          </a>
#         </li>
#         <li>
#          <a href="https://resume.naukri.com/resume-writing-services?fftid=101001" target="_blank" title="Text Resume">
#           Text Resume
#          </a>
#         </li>
#         <li>
#          <a href="https://resume.naukri.com/visual-resume-writing-services?fftid=101002" target="_blank" title="Visual Resume">
#           Visual Resume
#          </a>
#         </li>
#         <li>
#          <a href="https://resume.naukri.com/resume-quality-score?fftid=101003" target="_blank" title="Resume Quality Score - Free">
#           Resume Quality Score - Free
#          </a>
#         </li>
#         <li class="lastSib">
#          <a href="https://resume.naukri.com/resume-samples?fftid=101004" target="_blank" title="Resume Samples">
#           Resume Samples
#          </a>
#         </li>
#         <li class="header1">
#          <a title="Jobs For You">
#           Jobs For You
#          </a>
#         </li>
#         <li>
#          <a href="https://resume.naukri.com/job-alerts-on-mobile-mail?fftid=101011#jobmail" target="_blank" title="Jobs4U">
#           Jobs4U
#          </a>
#         </li>
#        </ul>
#        <ul class="group">
#         <li class="header1">
#          <a>
#           Recruiter Reach
#          </a>
#         </li>
#         <li>
#          <a href="https://resume.naukri.com/resume-display?fftid=101009" target="_blank" title="Resume Display">
#           Resume Display
#          </a>
#         </li>
#         <li>
#          <a href="https://resume.naukri.com/contact-recruiters-hr?fftid=101010" target="_blank" title="RecruiterConnection">
#           <span class="newStatus">
#           </span>
#           RecruiterConnection
#          </a>
#         </li>
#         <li class="lastSib">
#          <a href="https://resume.naukri.com/priority-job-application?fftid=101019" target="_blank" title="Priority Applicant">
#           <span class="newStatus">
#           </span>
#           Priority Applicant
#          </a>
#         </li>
#         <li class="header1">
#          <a>
#           Other
#          </a>
#         </li>
#         <li>
#          <a href="https://resume.naukri.com/frequently-asked-questions-faq/?fftid=101013" target="_blank" title="Help/FAQ">
#           Help / FAQ
#          </a>
#         </li>
#         <li>
#          <a href="https://resume.naukri.com/articles/?fftid=101014" target="_blank" title="Career Advice">
#           Career Advice
#          </a>
#         </li>
#         <li>
#          <a href="https://resume.naukri.com/contact-us?fftid=101015" target="_blank" title="Contact Us">
#           Contact Us
#          </a>
#         </li>
#        </ul>
#        <ul class="group">
#         <li class="header1">
#          <a>
#           Courses / Certifications
#          </a>
#         </li>
#         <li class="club">
#          <a href="https://learning.naukri.com/it-telecom-courses-certification-training-ct31?utm_source=naukri&amp;utm_medium=naukri_gnb&amp;utm_content=naukri_gnb&amp;utm_campaign=naukri_gnb_top&amp;fftid=naukri_gnb" target="_blank" title="IT &amp; Telecom">
#           IT &amp; Telecom
#          </a>
#          |
#          <a href="https://learning.naukri.com/project-management-courses-certification-training-st313?utm_source=naukri&amp;utm_medium=naukri_gnb&amp;utm_content=naukri_gnb&amp;utm_campaign=naukri_gnb_top&amp;fftid=naukri_gnb" target="_blank" title="PMP">
#           PMP
#          </a>
#         </li>
#         <li>
#          <a href="https://learning.naukri.com/banking-finance-analytics-courses-certification-training-ct35?utm_source=naukri&amp;utm_medium=naukri_gnb&amp;utm_content=naukri_gnb&amp;utm_campaign=naukri_gnb_top&amp;fftid=naukri_gnb" target="_blank" title="Banking &amp; Finance">
#           Banking &amp; Finance
#          </a>
#         </li>
#         <li>
#          <a href="https://learning.naukri.com/ifrs-certification?utm_source=naukri&amp;utm_medium=naukri_gnb&amp;utm_content=naukri_gnb&amp;utm_campaign=naukri_gnb_top&amp;fftid=naukri_gnb" target="_blank" title="IFRS">
#           IFRS
#          </a>
#         </li>
#         <li>
#          <a href="https://learning.naukri.com/data-science-analytics-courses-certification-training-st309?utm_source=naukri&amp;utm_medium=naukri_gnb&amp;utm_content=naukri_gnb&amp;utm_campaign=naukri_gnb_top&amp;fftid=naukri_gnb" target="_blank" title="Data Science , Analytics">
#           Data Science , Analytics
#          </a>
#         </li>
#         <li class="club">
#          <a href="https://learning.naukri.com/bpo-operations-engineering-courses-certification-training-ct41?utm_source=naukri&amp;utm_medium=naukri_gnb&amp;utm_content=naukri_gnb&amp;utm_campaign=naukri_gnb_top&amp;fftid=naukri_gnb" target="_blank" title="Operations">
#           Operations
#          </a>
#          |
#          <a href="https://learning.naukri.com/six-sigma-quality-courses-certification-training-st311?utm_source=naukri&amp;utm_medium=naukri_gnb&amp;utm_content=naukri_gnb&amp;utm_campaign=naukri_gnb_top&amp;fftid=naukri_gnb" target="_blank" title="Quality">
#           Quality
#          </a>
#         </li>
#         <li>
#          <a href="https://learning.naukri.com/digital-marketing-courses-certification-training-st301?utm_source=naukri&amp;utm_medium=naukri_gnb&amp;utm_content=naukri_gnb&amp;utm_campaign=naukri_gnb_top&amp;fftid=naukri_gnb" target="_blank" title="Digital Marketing">
#           Digital Marketing
#          </a>
#         </li>
#         <li>
#          <a href="https://learning.naukri.com/human-resources-administration-courses-certification-training-ct37?utm_source=naukri&amp;utm_medium=naukri_gnb&amp;utm_content=naukri_gnb&amp;utm_campaign=naukri_gnb_top&amp;fftid=naukri_gnb" target="_blank" title="HR &amp; Admin">
#           HR &amp; Admin
#          </a>
#         </li>
#         <li>
#          <a href="https://learning.naukri.com/leadership-management-courses-certification-training-ct49?utm_source=naukri&amp;utm_medium=naukri_gnb&amp;utm_content=naukri_gnb&amp;utm_campaign=naukri_gnb_top&amp;fftid=naukri_gnb" target="_blank" title="Leadership &amp; Strategy">
#           Leadership &amp; Strategy
#          </a>
#         </li>
#        </ul>
#       </div>
#      </li>
#      <li class='""'>
#       <a href="http://naukri.shiksha.com" target="_blank">
#        <span class="topIcon jobs More">
#        </span>
#        <div class="mTxt">
#         More
#        </div>
#       </a>
#       <div class="subMenu c3">
#        <ul class="group">
#         <li class="header1">
#          <a>
#           Management and Business
#          </a>
#         </li>
#         <li>
#          <a href="http://www.shiksha.com/mba/mba-home" target="_blank" title="MBA">
#           MBA
#          </a>
#         </li>
#         <li>
#          <a href="http://www.shiksha.com/mba/distance-mba-home" target="_blank" title="Distance MBA">
#           Distance MBA
#          </a>
#         </li>
#         <li class="lastSib">
#          <a href="http://www.shiksha.com/mba/executive-mba-home" target="_blank" title="Executive MBA">
#           Executive MBA
#          </a>
#         </li>
#         <li class="header1">
#          <a>
#           Information Technology
#          </a>
#         </li>
#         <li>
#          <a href="http://naukri.shiksha.com/mca-colleges-in-india-categorypage-10-98-1-0-0-1-1-2-0-none-1-1" target="_blank" title="MCA">
#           MCA
#          </a>
#         </li>
#        </ul>
#        <ul class="group">
#         <li>
#          <a href="http://naukri.shiksha.com/mca-distance-education-in-india-categorypage-10-97-1-0-0-1-1-2-0-none-1-1" target="_blank" title="Distance MCA">
#           Distance MCA
#          </a>
#         </li>
#         <li>
#          <a href="http://naukri.shiksha.com/computer-programming-language-courses-in-india-categorypage-10-105-1-0-0-1-1-2-0-none-1-1" target="_blank" title="Software Courses">
#           Software Courses
#          </a>
#         </li>
#         <li class="lastSib">
#          <a href="http://naukri.shiksha.com/cisco-certification-courses-in-india-categorypage-10-101-1-0-0-1-1-2-0-none-1-1" target="_blank" title="Hardware Courses">
#           Hardware Courses
#          </a>
#         </li>
#         <li class="header1">
#          <a>
#           Animation, Multimedia
#          </a>
#         </li>
#         <li>
#          <a href="http://naukri.shiksha.com/animation-courses-in-india-categorypage-12-89-1-0-0-1-1-2-0-none-1-1" target="_blank" title="Animation">
#           Animation
#          </a>
#         </li>
#         <li>
#          <a href="http://naukri.shiksha.com/graphic-designing-courses-in-india-categorypage-12-92-1-0-0-1-1-2-0-none-1-1" target="_blank" title="Graphic Designing">
#           Graphic Designing
#          </a>
#         </li>
#         <li>
#          <a href="http://naukri.shiksha.com/web-designing-courses-in-india-categorypage-12-93-1-0-0-1-1-2-0-none-1-1" target="_blank" title="Web Designing">
#           Web Designing
#          </a>
#         </li>
#        </ul>
#        <ul class="group">
#         <li class="header1">
#          <a>
#           Study Abroad
#          </a>
#         </li>
#         <li>
#          <a href="http://studyabroad.shiksha.com/mba-in-abroad-dc11508" target="_blank" title="MBA">
#           MBA
#          </a>
#         </li>
#         <li>
#          <a href="http://studyabroad.shiksha.com/ms-in-abroad-dc11509" target="_blank" title="MS">
#           MS
#          </a>
#         </li>
#         <li>
#          <a href="http://studyabroad.shiksha.com/be-btech-in-abroad-dc11510" target="_blank" title="BE/BTech">
#           BE/BTech
#          </a>
#         </li>
#        </ul>
#        <ul class="group">
#         <li class="header1">
#          <a>
#           More
#          </a>
#         </li>
#         <li>
#          <a href="https://careernavigator.naukri.com" target="_blank" title="Paycheck">
#           Paycheck
#          </a>
#         </li>
#         <li>
#          <a href="https://www.naukri.com/mobile" target="_blank" title="Naukri On Mobile">
#           Naukri On Mobile
#          </a>
#         </li>
#         <li>
#          <a href="http://blogs.naukri.com" target="_blank" title="Naukri Blog">
#           Blog
#          </a>
#         </li>
#        </ul>
#       </div>
#      </li>
#      <li>
#       <a href="https://login.naukri.com/nLogin/Login.php" id="login_Layer" title="Jobseeker Login">
#        <span class="topIcon jobs Login">
#        </span>
#        <div class="mTxt">
#         Login
#        </div>
#       </a>
#      </li>
#     </ul>
#     <div class="rghtSec fr menu nonLogged">
#      <ul class="notifySec">
#       <li>
#        <a class="blob" href="https://www.naukri.com/recommendedjobs" id="blobId" target="_blank">
#         <div class="topIcon notify">
#          <span>
#          </span>
#         </div>
#         <div class="mTxt">
#          Notifications
#          <span class="rJobCntr" id="rJobCntr">
#          </span>
#         </div>
#        </a>
#       </li>
#      </ul>
#      <ul class="otherSec">
#       <li class="first-child">
#        <a class="immediate" href="https://login.recruit.naukri.com" target="_blank" title="Employer Login">
#         Employer Zone
#        </a>
#       </li>
#       <li class="last-child">
#        <a class="immediate" href="https://recruit.naukri.com/rCommerce/demo/buy" target="_blank" title="Buy Online- RESDEX and Vacancy Listings">
#         <div>
#          Buy Online
#          <span class='\"smArw\"'>
#          </span>
#         </div>
#        </a>
#        <div class="subMenu">
#         <ul>
#          <li>
#           <a href="https://recruit.naukri.com/rCommerce/demo/buy" target="_blank" title="Buy Online- RESDEX and Vacancy Listings">
#            Buy Online
#           </a>
#          </li>
#          <li>
#           <a href="https://recruit.naukri.com/rCommerce/instaPost/default" target="_blank" title="Post an Insta Job">
#            Post an Insta Job
#           </a>
#          </li>
#         </ul>
#        </div>
#       </li>
#      </ul>
#     </div>
#     <input cache="true" domain=".naukri.com" id="blobNotificationURL" type="hidden" unreg="true" value="https://www.naukri.com/notify"/>
#     <div class="septr">
#     </div>
#    </div>
#   </div>
#   <script type="text/javascript">
#    if (!global.layers) {
#     global.layers = {}
# }
# if (!global.layers.loginLayer) {
#     global.layers.loginLayer = {};
# }
#
# global.layers.loginLayer.data = {
# 	callbackKey: 		1,
#     formAction:         "https://login.naukri.com/nLogin/Login.php",
#     URL:                "https://www.naukri.com/components/fb?app_id=103",
#     failURL:            "https://www.naukri.com/components/fb?app_id=103&fail=1",
#     forgot_pswd_url:    "https://login.naukri.com/nLogin/forgotpass.php",
#     registerURL:        "https://my.naukri.com//manager/resmanpage0.php"
# };
# global.layers.loginLayer.data.socialLogin = {
#     googleLogin:'https://login.naukri.com/nLogin/SocialLoginController.php?source=g&',
#     fbLogin:'https://login.naukri.com/nLogin/SocialLoginController.php?source=f&'
# };
# var redirectUrl = {
#     successLogin: "https://my.naukri.com",
#     captchaLogin: "https://login.naukri.com/nLogin/Login.php",
#     OTPLogin: "https://login.naukri.com/nLogin/Login.php?msg=6",
#     resetPassWrdLogin: "https://login.naukri.com/nLogin/resetpassnew.php?uid="
# };
#
#
# var loginDetails = {
#     newLogin : true,    // true if new login feature is to be shown else false.
#     ajaxURL : "https://www.naukri.com/loginapi/v5/login"     // Ajax URL on which API is to be hit.
# };
#
# var newRedirectUrl = {
#     successLogin: "https://my.naukri.com",
#     captchaLogin: "https://www.naukri.com/nlogin/login",
#     OTPLogin: "https://login.naukri.com/nLogin/Login.php?msg=6",
#     resetPassWrdLogin: "https://login.naukri.com/nLogin/resetpassnew.php?uid="
# };
# if (!global.layers.newLoginLayer) {
#     global.layers.newLoginLayer = {};
# }
# global.layers.newLoginLayer.data = {
#     callbackKey:        1,
#     formAction:         "https://login.naukri.com/nLogin/Login.php",
#     URL:                "https://www.naukri.com/components/fb?app_id=103",
#     failURL:            "https://www.naukri.com/components/fb?app_id=103&fail=1",
#     forgot_pswd_url:    "https://www.naukri.com/nlogin/forgotpassword",
#     registerURL:        "https://my.naukri.com//manager/resmanpage0.php"
# };
# global.layers.newLoginLayer.data.socialLogin = {
#     googleLogin:'https://login.naukri.com/nLogin/SocialLoginController.php?source=g&',
#     fbLogin:'https://login.naukri.com/nLogin/SocialLoginController.php?source=f&'
# };
#   </script>
#   <div>
#   </div>
#   <div class="bgBand">
#    <div class="blrLyr dspN">
#     <span class="close">
#     </span>
#    </div>
#    <div class="topBand">
#     <div class="wrap">
#      <ul class="tabs">
#       <li class="active">
#        <a href="https://www.naukri.com" title="All Jobs">
#         All Jobs
#        </a>
#       </li>
#       <li class=" target_premiumLayer">
#        <a data-ga-track="IIT-IIM Jobs|IIT-IIM Jobs" href="https://www.naukri.com/premium-jobs-for-iit-engineering-graduates" title="IIT/IIM Jobs">
#         IIT/IIM Jobs
#        </a>
#       </li>
#       <li>
#        <a data-ga-track="Govt Jobs|Govt Jobs" href="https://www.naukri.com/psu-government-jobs" title="Govt. Jobs">
#         Govt. Jobs
#        </a>
#       </li>
#       <li>
#        <a data-ga-track="International Jobs|International Jobs" href="https://www.naukri.com/international-jobs" title="International Jobs">
#         International Jobs
#        </a>
#       </li>
#       <li>
#        <a data-ga-track="GNBTopBand|WalkinJobs" href="https://www.naukri.com/walkin-jobs" title="Walk-in Jobs">
#         Walk-in Jobs
#        </a>
#       </li>
#      </ul>
#     </div>
#    </div>
#    <div class="wrap">
#     <ul class="breadcrumb">
#      <li>
#       <a data-ga-track="SrpBreadCrumb|Home" href="https://www.naukri.com">
#        Home
#       </a>
#      </li>
#      <li>
#       <a data-ga-track="SrpBreadCrumb|KeywordJobs" href="https://www.naukri.com/data scientist-jobs">
#        Data scientist Jobs
#       </a>
#      </li>
#     </ul>
#     <div class="qsbWrap">
#      <div class="qsbSec">
#       <div class="srcJob dspN">
#        Search Jobs
#       </div>
#       <form class="qsbFormJS" data-action="https://www.naukri.com/" data-domain="https://www.naukri.com/" data-error-message="Please enter Keywords or Location to search" id="qsbForm" method="post" name="qsbForm">
#        <div class="clrFx">
#         <input name="app_id" type="hidden" value="109">
#          <input name="qsb_section" type="hidden" value="home">
#           <div class="qsbfield">
#            <div class="suggest" data-max_suggestions="15" data-start_search_after="2" id="skill">
#             <div class="sWrap lftBrd">
#              <div class="iconWrap">
#               <span class="nLoder">
#               </span>
#              </div>
#              <div class="inpWrap">
#               <input class="sugInp" maxlength="250" name="qp" placeholder="Skills, Designations, Companies" rel="custom:1016" type="text" value="data scientist">
#               </input>
#              </div>
#             </div>
#            </div>
#            <div class="suggest" data-start_search_after="2" id="location">
#             <div class="sWrap">
#              <div class="iconWrap">
#               <span class="nLoder">
#               </span>
#              </div>
#              <div class="inpWrap">
#               <input autocomplete="off" class="sugInp w135" name="ql" placeholder="Location/Locality" rel="custom:1016" type="text" value="mumbai">
#               </input>
#              </div>
#             </div>
#            </div>
#            <div class="singleDD" data-value="Experience" id="exp_dd">
#             <div class="dWrap">
#              <span class="smArw">
#              </span>
#              <input autocomplete="off" class="sdTxt w85" name="qe" placeholder="Experience" readonly="" type="text"/>
#             </div>
#            </div>
#            <div class="singleDD" data-suggestor_min="-1" data-value="Salary" id="salary_dd">
#             <div class="dWrap">
#              <input autocomplete="off" class="sdTxt w85" name="qm" placeholder="Salary" readonly="" type="text"/>
#              <span class="smArw">
#              </span>
#             </div>
#            </div>
#           </div>
#           <button class="qsbSrch blueBtn" id="qsbFormBtn" type="submit">
#            Search
#           </button>
#          </input>
#         </input>
#        </div>
#        <div class="advnLink">
#         <i class="erLbl fl" id="qsbError">
#         </i>
#         <a class="advSrch fr target_advanceSeachLayer" href="javascript:;">
#          Advanced Search
#         </a>
#        </div>
#       </form>
#       <div class="rcntSrchWidget">
#       </div>
#      </div>
#      <script type="text/javascript">
#       var qsbModel = {
#     autoCompleteURL   : 'https://suggest.naukri.com/suggest/autosuggest?',
#     checkVersionURL : "https://suggest.naukri.com/suggest/v?",
#     relatedConceptURL  : 'https://suggest.naukri.com/suggest/autoconcepts?',
#     prefetchingURL  : 'https://suggest.naukri.com/suggest/prefetch?',
#     maxHeight       : 388,
#     multiSearch     : 1,
#     maxSuggestions  : 15,
#     startSearchAfter: 0,
#     searchIcon      : 1,
#     pskillCategory  : {skill:'Skills',title:'Designations',company:'Company'},
#     formID          : 'qsbForm',
#     appID           : 109,
#     sourceID        : 109,
#     cookieDomainName: '.naukri.com',
#     trackingURL     : "https://suggestlg.naukimg.com/logger/log",
#     vertical        : '',
#             qparams         : {'pFarea':18}
#     };
#
# var suggParams = qsbModel;
#      </script>
#     </div>
#    </div>
#   </div>
#   <div class="mainSec">
#    <div class="wrap">
#     <div class="cluster fl">
#      <div class="sugSearch">
#       <h3>
#        Find Jobs For
#       </h3>
#       <div>
#        <h3 class="sugSearchCtgr">
#         Designations
#        </h3>
#        <ul class="sugSearchItems">
#         <li>
#          <a href="https://www.naukri.com/data-analyst-jobs-in-mumbai" qp="Data Analyst" title="Data Analyst Jobs in Mumbai">
#           Data Analyst
#          </a>
#         </li>
#         <li>
#          <a href="https://www.naukri.com/statistical-analyst-jobs-in-mumbai" qp="Statistical Analyst" title="Statistical Analyst Jobs in Mumbai">
#           Statistical Analyst
#          </a>
#         </li>
#         <li>
#          <a href="https://www.naukri.com/analytics-consultant-jobs-in-mumbai" qp="Analytics Consultant" title="Analytics Consultant Jobs in Mumbai">
#           Analytics Consultant
#          </a>
#         </li>
#         <li>
#          <a href="https://www.naukri.com/sas-programmer-analyst-jobs-in-mumbai" qp="SAS Programmer Analyst" title="SAS Programmer Analyst Jobs in Mumbai">
#           SAS Programmer Analyst
#          </a>
#         </li>
#         <li>
#          <a href="https://www.naukri.com/business-analyst-jobs-in-mumbai" qp="Business Analyst" title="Business Analyst Jobs in Mumbai">
#           Business Analyst
#          </a>
#         </li>
#         <span class="more" id="desig">
#          ...more
#         </span>
#         <ul class="moreItems">
#          <li>
#           <a href="https://www.naukri.com/hadoop-developer-jobs-in-mumbai" qp="Hadoop Developer" title="Hadoop Developer Jobs in Mumbai">
#            Hadoop Developer
#           </a>
#          </li>
#          <li>
#           <a href="https://www.naukri.com/data-engineer-jobs-in-mumbai" qp="Data Engineer" title="Data Engineer Jobs in Mumbai">
#            Data Engineer
#           </a>
#          </li>
#          <li>
#           <a href="https://www.naukri.com/analytics-manager-jobs-in-mumbai" qp="Analytics Manager" title="Analytics Manager Jobs in Mumbai">
#            Analytics Manager
#           </a>
#          </li>
#         </ul>
#        </ul>
#        <h3 class="sugSearchCtgr">
#         Skills
#        </h3>
#        <ul class="sugSearchItems">
#         <li>
#          <a href="https://www.naukri.com/machine-learning-jobs-in-mumbai" qp="Machine Learning" title="Machine Learning Jobs in Mumbai">
#           Machine Learning
#          </a>
#         </li>
#         <li>
#          <a href="https://www.naukri.com/business-analytics-jobs-in-mumbai" qp="Business Analytics" title="Business Analytics Jobs in Mumbai">
#           Business Analytics
#          </a>
#         </li>
#         <li>
#          <a href="https://www.naukri.com/hadoop-jobs-in-mumbai" qp="Hadoop" title="Hadoop Jobs in Mumbai">
#           Hadoop
#          </a>
#         </li>
#         <li>
#          <a href="https://www.naukri.com/sas-jobs-in-mumbai" qp="SAS" title="SAS Jobs in Mumbai">
#           SAS
#          </a>
#         </li>
#         <li>
#          <a href="https://www.naukri.com/statistical-modeling-jobs-in-mumbai" qp="Statistical Modeling" title="Statistical Modeling Jobs in Mumbai">
#           Statistical Modeling
#          </a>
#         </li>
#         <span class="more" id="skills">
#          ...more
#         </span>
#         <ul class="moreItems">
#          <li>
#           <a href="https://www.naukri.com/predictive-modeling-jobs-in-mumbai" qp="Predictive Modeling" title="Predictive Modeling Jobs in Mumbai">
#            Predictive Modeling
#           </a>
#          </li>
#          <li>
#           <a href="https://www.naukri.com/data-mining-jobs-in-mumbai" qp="Data Mining" title="Data Mining Jobs in Mumbai">
#            Data Mining
#           </a>
#          </li>
#         </ul>
#        </ul>
#       </div>
#      </div>
#      <div class="refine">
#       <h3 class="small_title">
#        Refine Results
#       </h3>
#       <form id="clstrFrm" name="clstrFrm">
#        <div class="acord" id="acord">
#        </div>
#        <input id="clstrVals" name="qclus" type="hidden">
#        </input>
#       </form>
#      </div>
#     </div>
#    </div>
#   </div>
#  </body>
# </html>
# <div class="ltBx clstr lightbox" id="cluster">
#  <div class="ltGlobalHd">
#   <div class="ltGlobalTtl">
#   </div>
#   <a class="ltGlobalCls" href="javascript:" id="closeClstr">
#   </a>
#  </div>
#  <div class="ltCntnt">
#   <div class="clusBx" id="clstrLBFrm" name="clstrFrm">
#    <div class="ofHd">
#    </div>
#   </div>
#   <iframe class="dspN" height="0" id="login-iframe" name="login-iframe" width="0">
#   </iframe>
#  </div>
# </div>
# <div class="container fl">
#  <div class="srp_container fl ">
#   <div class="row srp_head">
#    <div class="srp_count">
#     <div class="count">
#      <div class="small_title">
#       <span class="cnt" style="font-weight:300;" title="1-50 of 342">
#        1-50 of 342
#       </span>
#       <h1>
#        <span class="frst" title="Data Scientist">
#         Data Scientist
#        </span>
#        <span class="scnd" title="Jobs in Mumbai">
#         Jobs in Mumbai
#        </span>
#       </h1>
#      </div>
#     </div>
#     <div class="tools">
#      Sort by:
#      <div class="sortBy">
#       <span class="dropText">
#       </span>
#       <em class="downArrow">
#       </em>
#       <div class="drop">
#        <em class="tip">
#        </em>
#        <ul class="list">
#         <li class=" item" rel="f">
#          Date
#         </li>
#         <li class="sel item" rel="r">
#          Relevance
#         </li>
#        </ul>
#       </div>
#      </div>
#      <span class="toggle large active" title="Detailed View">
#       <em>
#       </em>
#      </span>
#      <span class="toggle short " title="Listing View">
#       <em>
#       </em>
#      </span>
#     </div>
#    </div>
#   </div>
#   <div class="srp_fixed">
#    <form class="save_search" id="frmSSA" name="saveSearchForm">
#     <div class="msgBar dspN" id="ssaMsgBar">
#      <div class="cnt">
#      </div>
#     </div>
#     <span class="getJobText">
#      Get jobs in Inbox -
#     </span>
#     <div class="details ">
#      <div class="field searchName">
#       <input maxlength="100" name="janame" placeholder="Name your search" rel="required:1023,specialChar:1027"/>
#       <i class="erLbl" id="janame_err">
#       </i>
#      </div>
#      <div class="field email">
#       <input maxlength="100" name="email" placeholder="Email ID" rel="required:1024,custom:1001"/>
#       <i class="erLbl" id="email_err">
#       </i>
#      </div>
#     </div>
#     <input id="ssaSbt" name="save" type="submit" value="Save"/>
#    </form>
#   </div>
#   <div class="row " id="100318003940" itemscope="" itemtype="http://schema.org/JobPosting" type="tuple">
#    <a class="content" count="1" href="https://www.naukri.com/job-listings-Am-dm-manager-Data-Scientist-Insurance-2-8-Years-Crescendo-Global-Services-Mumbai-2-to-7-years-100318003940?src=jobsearchDesk&amp;sid=15207450423413&amp;xp=1&amp;px=1" target="_blank">
#     <div class="banner">
#      <img alt="Crescendo Global Services" src="https://img.naukimg.com/logo_images/v2/2020094.gif"/>
#     </div>
#     <ul>
#      <li class="desig" itemprop="title" title="Am/dm/manager Data Scientist Insurance (2-8 Years)">
#       Am/dm/manager Data Scientist Insurance (2-8 Years)
#      </li>
#     </ul>
#     <span class="org" itemprop="hiringOrganization">
#      Crescendo Global Services
#     </span>
#     <span class="exp" itemprop="experienceRequirements">
#      <em>
#      </em>
#      2-7 yrs
#     </span>
#     <span class="loc">
#      <em>
#      </em>
#      <span itemprop="jobLocation">
#       Mumbai
#      </span>
#     </span>
#     <div class="more">
#      <span class="label">
#       Keyskills:
#      </span>
#      <div class="desc">
#       <span class="skill" itemprop="skills">
#        Deep Learning, Text Mining, Natural Language Processing, Data Science...
#       </span>
#      </div>
#      <span class="label">
#       Job Description:
#      </span>
#      <span class="desc" itemprop="description">
#       AM/DM/Manager Data scientist Insurance (2-8 years)  An exciting opportunity as a Data Scientist ...
#      </span>
#     </div>
#    </a>
#    <span class="action jobType hotjob" title="Hot Job">
#     <em>
#     </em>
#    </span>
#    <div class="other_details">
#     <span class="action savejob fav " jid="100318003940" title=" Save this job ">
#      <em>
#      </em>
#     </span>
#     <span class="salary " itemprop="baseSalary">
#      <em>
#      </em>
#      7,00,000 - 14,00,000 P.A.
#     </span>
#     <div class="rec_details">
#      Posted  by
#      <a class="rec_img" href="https://www.naukri.com/recruiters/profile/anirudhkapoor-3054226?xz=0_0_7" target="_blank">
#       <img height="25px" src="https://naukrirecruiter.naukri.com/profilePic/getpic?pid=1504687147rp3054226_small2" width="25px"/>
#      </a>
#      <a class="rec_name active" href="https://www.naukri.com/recruiters/profile/anirudhkapoor-3054226?xz=0_0_7" target="_blank" title="Job Posted by  Nikita Sharma ">
#       Nikita Sharma
#      </a>
#      ,
#      <span class="date">
#       1 day ago
#      </span>
#     </div>
#    </div>
#   </div>
#   <div class="row " id="090318900343" itemscope="" itemtype="http://schema.org/JobPosting" type="tuple">
#    <a class="content" count="2" href="https://www.naukri.com/job-listings-Data-Scientist-Truebil-com-Mumbai-2-to-5-years-090318900343?src=jobsearchDesk&amp;sid=15207450423413&amp;xp=2&amp;px=1" target="_blank">
#     <ul>
#      <li class="desig" itemprop="title" title="Data Scientist">
#       Data Scientist
#      </li>
#     </ul>
#     <span class="org" itemprop="hiringOrganization">
#      Truebil.com
#     </span>
#     <span class="exp" itemprop="experienceRequirements">
#      <em>
#      </em>
#      2-5 yrs
#     </span>
#     <span class="loc">
#      <em>
#      </em>
#      <span itemprop="jobLocation">
#       Mumbai
#      </span>
#     </span>
#     <div class="more">
#      <span class="label">
#       Keyskills:
#      </span>
#      <div class="desc">
#       <span class="skill" itemprop="skills">
#        SAS, Excel, R, SQL, Analytics Reporting, Statistical Modeling...
#       </span>
#      </div>
#      <span class="label">
#       Job Description:
#      </span>
#      <span class="desc" itemprop="description">
#       Roles &amp; Responsibilities:  - You will be working on building our proprietary systems using ...
#      </span>
#     </div>
#    </a>
#    <span class="action jobType premium" title="">
#     <em>
#     </em>
#    </span>
#    <div class="other_details">
#     <span class="action savejob fav " jid="090318900343" title=" Save this job ">
#      <em>
#      </em>
#     </span>
#     <span class="salary " itemprop="baseSalary">
#      <em>
#      </em>
#      Not disclosed
#     </span>
#     <div class="rec_details">
#      Posted  by
#      <a class="rec_img" href="https://www.naukri.com/recruiters/profile/nikitadaga?xz=0_0_7" target="_blank">
#      </a>
#      <a class="rec_name active" href="https://www.naukri.com/recruiters/profile/nikitadaga?xz=0_0_7" target="_blank" title="Job Posted by  Mayuresh Samant ">
#       Mayuresh Samant
#      </a>
#      ,
#      <span class="date">
#       2 days ago
#      </span>
#     </div>
#    </div>
#   </div>
#   <div class="row " id="030318003636" itemscope="" itemtype="http://schema.org/JobPosting" type="tuple">
#    <a class="content" count="3" href="https://www.naukri.com/job-listings-Data-Scientist-Harjai-Computers-Pvt-Ltd-Mumbai-1-to-3-years-030318003636?src=jobsearchDesk&amp;sid=15207450423413&amp;xp=3&amp;px=1" target="_blank">
#     <ul>
#      <li class="desig" itemprop="title" title="Data Scientist">
#       Data Scientist
#      </li>
#     </ul>
#     <span class="org" itemprop="hiringOrganization">
#      Harjai Computers Pvt Ltd
#     </span>
#     <span class="exp" itemprop="experienceRequirements">
#      <em>
#      </em>
#      1-3 yrs
#     </span>
#     <span class="loc">
#      <em>
#      </em>
#      <span itemprop="jobLocation">
#       Mumbai
#      </span>
#     </span>
#     <div class="more">
#      <span class="label">
#       Keyskills:
#      </span>
#      <div class="desc">
#       <span class="skill" itemprop="skills">
#        Data Science, Machine Learning, R, Python
#       </span>
#      </div>
#     </div>
#    </a>
#    <span class="action jobType classified" title="Classified Job">
#     <em>
#     </em>
#    </span>
#    <div class="other_details">
#     <span class="action savejob fav " jid="030318003636" title=" Save this job ">
#      <em>
#      </em>
#     </span>
#     <span class="salary " itemprop="baseSalary">
#      <em>
#      </em>
#      Not disclosed
#     </span>
#     <div class="rec_details">
#      Posted  by
#      <a class="rec_img" href="https://www.naukri.com/recruiters/profile/divyasharma-3269404?xz=0_0_7" target="_blank">
#      </a>
#      <a class="rec_name active" href="https://www.naukri.com/recruiters/profile/divyasharma-3269404?xz=0_0_7" target="_blank" title="Job Posted by  Divya Sharma ">
#       Divya Sharma
#      </a>
#      ,
#      <span class="date">
#       1 day ago
#      </span>
#     </div>
#    </div>
#   </div>
#   <div class="row " id="090318001216" itemscope="" itemtype="http://schema.org/JobPosting" type="tuple">
#    <a class="content" count="4" href="https://www.naukri.com/job-listings-Looking-for-Data-Scientist-Tech-Mahindra-Ltd-Mumbai-5-to-9-years-090318001216?src=jobsearchDesk&amp;sid=15207450423413&amp;xp=4&amp;px=1" target="_blank">
#     <div class="banner">
#      <img alt="Tech Mahindra Ltd." src="https://img.naukimg.com/logo_images/v2/100007.gif"/>
#     </div>
#     <ul>
#      <li class="desig" itemprop="title" title="Looking for Data Scientist">
#       Looking for Data Scientist
#      </li>
#     </ul>
#     <span class="org" itemprop="hiringOrganization">
#      Tech Mahindra Ltd.
#     </span>
#     <span class="exp" itemprop="experienceRequirements">
#      <em>
#      </em>
#      5-9 yrs
#     </span>
#     <span class="loc">
#      <em>
#      </em>
#      <span itemprop="jobLocation">
#       Mumbai
#      </span>
#     </span>
#     <div class="more">
#      <span class="label">
#       Keyskills:
#      </span>
#      <div class="desc">
#       <span class="skill" itemprop="skills">
#        Data Science
#       </span>
#      </div>
#     </div>
#    </a>
#    <span class="action jobType prefjob" title="Preferred Job">
#     <em>
#     </em>
#    </span>
#    <div class="other_details">
#     <span class="action savejob fav " jid="090318001216" title=" Save this job ">
#      <em>
#      </em>
#     </span>
#     <span class="salary " itemprop="baseSalary">
#      <em>
#      </em>
#      7,00,000 - 12,00,000 P.A.
#     </span>
#     <div class="rec_details">
#      Posted  by
#      <a class="rec_img" href="https://www.naukri.com/recruiters/profile/bhavani-1686732?xz=0_0_7" target="_blank">
#      </a>
#      <a class="rec_name active" href="https://www.naukri.com/recruiters/profile/bhavani-1686732?xz=0_0_7" target="_blank" title="Job Posted by  Bhavani ">
#       Bhavani
#      </a>
#      ,
#      <span class="date">
#       2 days ago
#      </span>
#     </div>
#    </div>
#   </div>
#   <div class="row " id="090318005810" itemscope="" itemtype="http://schema.org/JobPosting" type="tuple">
#    <a class="content" count="5" href="https://www.naukri.com/job-listings-Data-Scientist-UBS-Business-Solutions-India-Pvt-Ltd-Navi-Mumbai-3-to-6-years-090318005810?src=jobsearchDesk&amp;sid=15207450423413&amp;xp=5&amp;px=1" target="_blank">
#     <div class="banner">
#      <img alt="UBS Business Solutions (India) Pvt. Ltd." src="https://img.naukimg.com/logo_images/v2/2551272.gif"/>
#     </div>
#     <ul>
#      <li class="desig" itemprop="title" title="Data Scientist">
#       Data Scientist
#      </li>
#     </ul>
#     <span class="org" itemprop="hiringOrganization">
#      UBS Business Solutions (India) Pvt. Ltd.
#     </span>
#     <span class="exp" itemprop="experienceRequirements">
#      <em>
#      </em>
#      3-6 yrs
#     </span>
#     <span class="loc">
#      <em>
#      </em>
#      <span itemprop="jobLocation">
#       Navi Mumbai
#      </span>
#     </span>
#     <div class="more">
#      <span class="label">
#       Keyskills:
#      </span>
#      <div class="desc">
#       <span class="skill" itemprop="skills">
#        data scientist, data science, analytics, tableau, bi
#       </span>
#      </div>
#     </div>
#    </a>
#    <span class="action jobType prefjob" title="Preferred Job">
#     <em>
#     </em>
#    </span>
#    <div class="other_details">
#     <span class="action savejob fav " jid="090318005810" title=" Save this job ">
#      <em>
#      </em>
#     </span>
#     <span class="salary " itemprop="baseSalary">
#      <em>
#      </em>
#      Not disclosed
#     </span>
#     <div class="rec_details">
#      Posted  by
#      <a class="rec_name" title="Job Posted by  HR ">
#       HR
#      </a>
#      ,
#      <span class="date">
#       2 days ago
#      </span>
#     </div>
#    </div>
#   </div>
#   <div class="row " id="101117005683" itemscope="" itemtype="http://schema.org/JobPosting" type="tuple">
#    <a class="content" count="6" href="https://www.naukri.com/job-listings-Principal-Data-Scientist-HERE-Solutions-India-Private-Limited-Mumbai-8-to-11-years-101117005683?src=jobsearchDesk&amp;sid=15207450423413&amp;xp=6&amp;px=1" target="_blank">
#     <ul>
#      <li class="desig" itemprop="title" title="Principal Data Scientist">
#       Principal Data Scientist
#      </li>
#     </ul>
#     <span class="org" itemprop="hiringOrganization">
#      HERE Solutions India Private Limited
#     </span>
#     <span class="exp" itemprop="experienceRequirements">
#      <em>
#      </em>
#      8-11 yrs
#     </span>
#     <span class="loc">
#      <em>
#      </em>
#      <span itemprop="jobLocation">
#       Mumbai
#      </span>
#     </span>
#     <div class="more">
#      <span class="label">
#       Keyskills:
#      </span>
#      <div class="desc">
#       <span class="skill" itemprop="skills">
#        Machine Learning, Deep Learning, Computer Vision, Analytics, Big Data, Data...
#       </span>
#      </div>
#      <span class="label">
#       Job Description:
#      </span>
#      <span class="desc" itemprop="description">
#       Principal Data Scientist  - Deep Learning    Join a team of highly skilled and ...
#      </span>
#     </div>
#    </a>
#    <span class="action jobType premium" title="">
#     <em>
#     </em>
#    </span>
#    <div class="other_details">
#     <span class="action savejob fav " jid="101117005683" title=" Save this job ">
#      <em>
#      </em>
#     </span>
#     <span class="salary " itemprop="baseSalary">
#      <em>
#      </em>
#      Not disclosed
#     </span>
#     <div class="rec_details">
#      Posted  by
#      <a class="rec_name" title="Job Posted by  HR ">
#       HR
#      </a>
#      ,
#      <span class="date">
#       3 days ago
#      </span>
#     </div>
#    </div>
#   </div>
#   <div class="row " id="070318004320" itemscope="" itemtype="http://schema.org/JobPosting" type="tuple">
#    <a class="content" count="7" href="https://www.naukri.com/job-listings-Deep-Learning-Engineer-Senior-Data-Scientist-NanoNets-Mumbai-5-to-10-years-070318004320?src=jobsearchDesk&amp;sid=15207450423413&amp;xp=7&amp;px=1" target="_blank">
#     <ul>
#      <li class="desig" itemprop="title" title="Deep Learning Engineer ( Senior Data Scientist)">
#       Deep Learning Engineer ( Senior Data Scientist)
#      </li>
#     </ul>
#     <span class="org" itemprop="hiringOrganization">
#      NanoNets
#     </span>
#     <span class="exp" itemprop="experienceRequirements">
#      <em>
#      </em>
#      5-10 yrs
#     </span>
#     <span class="loc">
#      <em>
#      </em>
#      <span itemprop="jobLocation">
#       Mumbai
#      </span>
#     </span>
#     <div class="more">
#      <span class="label">
#       Keyskills:
#      </span>
#      <div class="desc">
#       <span class="skill" itemprop="skills">
#        Deep Learning Engineer, Data Scientist, Deep Learning, Python, Tensorflow...
#       </span>
# ...
#        Access Database
#       </a>
#      </li>
#      <li>
#       <a href="https://recruit.naukri.com/" target="_blank" title="Manage Responses">
#        Manage Responses
#       </a>
#      </li>
#      <li>
#       <a href="https://www.naukrirms.com/" target="_blank" title="Recruitment Software, inclusive of Applicant Tracking System">
#        Naukri RMS
#       </a>
#      </li>
#      <li>
#       <a href="https://recruit.naukri.com/rCommerce/demo/buy" target="_blank" title="Buy Online">
#        Buy Online
#       </a>
#      </li>
#      <li>
#       <a href="http://w5.naukri.com/fdbck/main/feedback.php?app_id=18" target="_blank" title="Report a Problem">
#        Report a Problem
#       </a>
#      </li>
#      <li class="textual">
#       <a>
#        Recruiters from USA, call
#       </a>
#      </li>
#      <li class="textual">
#       <a target="_blank">
#        Toll Free # 1866-557-3340
#       </a>
#      </li>
#     </ul>
#    </div>
#    <div class="followus">
#     <a style="display:block;padding-bottom:5px;" target="_blank">
#      Follow Us
#     </a>
#     <a class="icons fb" href="https://www.facebook.com/Naukri" target="_blank" title="Follow Naukri.com on Facebook">
#     </a>
#     <a class="icons twitter" href="https://twitter.com/naukri" target="_blank" title="Follow Naukri.com on Twitter">
#     </a>
#     <a class="icons ln" href="http://www.linkedin.com/company/naukri.com" target="_blank" title="Follow Naukri.com on LinkedIn">
#     </a>
#     <a class="icons gplus" href="https://plus.google.com/+Naukri" target="_blank" title="Follow Naukri.com on Google+">
#     </a>
#    </div>
#    <div class="">
#     <ul>
#      <li class="header">
#       <a target="_blank">
#        Ambition Box
#       </a>
#      </li>
#      <li>
#       <a href="http://ambitionbox.com/interviews?utm_source=naukri&amp;utm_medium=footer" target="_blank" title="Interview Questions">
#        Interview Questions
#       </a>
#      </li>
#      <li>
#       <a href="http://ambitionbox.com/companies?utm_source=naukri&amp;utm_medium=footer" rel="noindex nofollow" target="_blank" title="About Companies">
#        About Companies
#       </a>
#      </li>
#      <li>
#       <a href="http://ambitionbox.com/contribute?utm_source=naukri&amp;utm_medium=footer" target="_blank" title="Share Interview Story">
#        Share Interview Story
#       </a>
#      </li>
#     </ul>
#    </div>
#   </div>
#  </div>
# </div>
# <div class="footer carousel">
#  <div class="wrap" style="text-align:center;">
#   <span class="label">
#    Partner Sites
#   </span>
#   <div class="nCarousel dspIB">
#    <ul class="list">
#     <li class="item">
#      <a class="nnacres" href="http://www.99acres.com/" target="_blank">
#      </a>
#     </li>
#     <li class="item">
#      <a class="jeevansathi" href="http://www.jeevansathi.com/" target="_blank">
#      </a>
#     </li>
#     <li class="item">
#      <a class="ng" href="http://www.naukrigulf.com/" target="_blank">
#      </a>
#     </li>
#     <li class="item">
#      <a class="firstNaukri" href="http://www.firstnaukri.com/" target="_blank">
#      </a>
#     </li>
#     <li class="item">
#      <a class="brijj" href="http://www.brijj.com/" target="_blank">
#      </a>
#     </li>
#     <li class="item">
#      <a class="allChkDeal" href="http://www.allcheckdeals.com/" target="_blank">
#      </a>
#     </li>
#     <li class="item">
#      <a class="shiksha" href="http://www.shiksha.com/" target="_blank">
#      </a>
#     </li>
#     <li class="item">
#      <a class="policyBazaar" href="https://www.policybazaar.com/" target="_blank">
#      </a>
#     </li>
#     <li class="item">
#      <a class="zomato" href="http://www.zomato.com" target="_blank">
#      </a>
#     </li>
#     <li class="item">
#      <a class="meritnation" href="http://www.meritnation.com/" target="_blank">
#      </a>
#     </li>
#     <li class="item">
#      <a class="mydalal" href="http://www.mydala.com/" target="_blank">
#      </a>
#     </li>
#     <li class="item">
#      <a class="paisaBazaar" href="http://www.paisabazaar.com/" target="_blank">
#      </a>
#     </li>
#    </ul>
#   </div>
#  </div>
# </div>
# <div class="footer disclaimer">
#  <div class="wrap" style="text-align:center;">
#   All rights reserved @ 2018 Info Edge (India) Ltd.
#  </div>
# </div>
# <link href="https://fonts.googleapis.com/css?family=Roboto:300,400,700" media="all" rel="stylesheet" type="text/css"/>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.11.0/jquery.min.js">
# </script>
# <script>
#  if (typeof jQuery == 'undefined') {
#                 document.write(decodeURI("%3Cscript src='https://static.naukimg.com/s/0/0/j/jquery.min.js' type='text/javascript'%3E%3C/script%3E"));
#               }
# </script>
# <script src="https://static.naukimg.com/s/4/101/j/plugins_v46.min.js" type="text/javascript">
# </script>
# <script src="https://static.naukimg.com/s/4/101/j/pluginsSubM_v25.min.js" type="text/javascript">
# </script>
# <script src="https://static.naukimg.com/s/4/101/j/jCommonPlugins_v80.min.js" type="text/javascript">
# </script>
# <script src="https://static.naukimg.com/s/4/109/j/srpCalls_v34.min.js" type="text/javascript">
# </script>
# <!--[if lte IE 10]>
#             <script src="multiColumnSupport not found" type="text/javascript"></script>
#            <![endif]-->
# <script type="text/javascript">
#  var src = "jobsearchDesk";
#       var username='';
#              var currentUrl = encodeURIComponent(window.location);
#        var urlSaveJob = "https://www.naukri.com/jd/saveJob?redUrl="+currentUrl;
#        var urlDeleteSavedJob = "https://www.naukri.com/jd/deleteSavedJob?redUrl="+currentUrl;
#             var searchParam = {};
#         searchParam["qp"]     = "data scientist";
#         searchParam["ql"]     = "mumbai";
#         searchParam["qe"]     = "";
#         searchParam["qm"]     = "";
#         searchParam["qx"]     = "";
#         searchParam['qi[]']   = null;
#         searchParam['qf[]']   = null;
#         searchParam['qr[]']   = null;
#         searchParam['qs']     = "r";
#         searchParam['qo']     = "";
#         searchParam['qjt[]']     = "";
#         searchParam['qk[]']   = null;
#         searchParam['qwdt']  =  "";
#         searchParam['qsb_section']  =  "home";
#         searchParam['qpremTagLabel']  =  "";
#         searchParam['sid'] = "15207450423413";
#
#         searchParam['qwd[]']  = null;
#         searchParam['qcf[]']  = null;
#         searchParam['qci[]']  = null;
#         searchParam['qck[]']  = null;
#         searchParam['edu[]']  = null;
#         searchParam['qcug[]'] = null;
#         searchParam['qcpg[]'] = null;
#         searchParam['qctc[]'] = null;
#         searchParam['qco[]']  = null;
#         searchParam['qcjt[]'] = null;
#         searchParam['qcr[]']  = null;
#         searchParam['qcl[]']  = null;
#   searchParam['qrefresh'] = null;
#         searchParam['xt'] = "adv";
#   searchParam['qtc[]'] = null;
#         searchParam['fpsubmiturl']  = "https://www.naukri.com/data-scientist-jobs-in-mumbai";
#         searchParam['qlcl[]']  = null;
#         searchParam['latLong']  = null;
# </script>
# <script type="text/javascript">
#  $('div[type=tuple]').highlight([], {element: 'font',className: 'hlite' ,  wordsOnly: true});
#        var ssaUrl = 'https://www.naukri.com/alert/createssa';
#        var qsb_section='home';
#        var srchCountUrl = 'https://www.naukri.com/srchcount';
#        var sendSrchCountAjax = 1;
#        var imsUrl="https://www.naukri.com/ims/intercept";
#        var imsParams="&id=&logstr=dummyXid-dummyXZ-jobsearchDesk--F-0-1-&flowtype=show&appid=107&crossdomain=false&closebtn=y";
#        var localityLabel = {"#25.20.105.6710|19.110501_72.856393":"Chakala-Mumbai","#25.20.105.6743|19.05656_72.85352":"Bandra Kurla Complex-Mumbai","#25.20.105.7156|18.90369_72.81296":"Colaba-Mumbai","#25.20.105.6476|19.117516_72.908449":"Powai-Mumbai"};
#               var crossDomain="";
#        if(crossDomain == 'true')
#        {
#          var crossDomainParams = true;
#        }
#        else {
#          var crossDomainParams = false;
#        }
#
#        applyBtnAction(showApplyBar);
#
# var ffAdObj={belly:{url:'/bellyffad',kwd:'data scientist',adPlaceHolder:"srp_right"},
#             right:{url:'/rightpanelffad',kwd:'data scientist',adPlaceHolder:"srp_belly"}
#             };
#
# var nlAdObj = {belly:{url:'/jobsearch/nlbellyad',resid:global.resid ,kwd:'data scientist',adPlaceHolder:"srp_belly"},
#             right:{url:'/jobsearch/nlrightpanelad',resid:global.resid ,kwd:'data scientist',adPlaceHolder:"srp_right"}
#             };
#
#                 var clusterorder = ["walkindate", "freshness", "CITY", "topCompanyId", "indtype", "CTC_RANGE", "education", "toj", "jobType"];
#     var clVersion = 3;
#         var cl = {};
#                             cl["freshness"] = $.parseJSON(freshnessMap);
#                     cl["ctc"] = $.parseJSON(ctcMap);
#                                 $.extend(cl, {"topCompanyId":{"#100007":1,"#532857":1,"#183700":7,"#13972":2,"#2584":1,"#10081":1,"#54819":1,"#97158":1,"#91587":1,"#6037":1,"#183587":1,"#68845":1,"#30163":1,"#571":1,"#6946":1,"#976180":1,"#144993":1,"#395661":1},"toj":{"#1":232,"#2":110},"LOCALITY_ID":{"#25.20.105.6710|19.110501_72.856393":2,"#25.20.105.6743|19.05656_72.85352":2,"#25.20.105.7156|18.90369_72.81296":1,"#25.20.105.6476|19.117516_72.908449":1},"CTC_RANGE":{"#0to3":12,"#3to6":60,"#6to10":113,"#10to15":80,"#15to25":71,"#25to50":28,"#50to75":3},"indtype":{"#25":154,"#14":44,"#63":30,"#48":23,"#52":15,"#7":12,"#34":10,"#17":6,"#27":5,"#19":4,"#22":4,"#32":4,"#26":4,"#15":3,"#9":3,"#2":3,"#37":2,"#13":2,"#8":2,"#29":2,"#35":1,"#46":1,"#21":1,"#18":1,"#38":1},"walkinJobs":[],"CITY":{"#25.20.105":322,"#25.17.74":25,"#25.20.106":5,"#25.20.190":18,"#25.20.109":18,"#25.9.31":15,"#25.29.146":12,"#25.1.4":8,"#25.9.30":5,"#26.0.0":3,"#25.31.172":3,"#25.33.183":2,"#25.12.36":2,"#25.29.147":2,"#25.20.269":1,"#25.18.93":1,"#23.0.0":1,"#25.18.195":1,"#25.12.48":1,"#25.13.54":1,"#25.1.11":1,"#25.18.86":1},"education":{"ug#18":176,"ug#11":157,"ug#17":46,"pg#19":165,"pg#20":141,"ug#10":40,"ug#3":23,"ug#1":15,"ug#4":12,"ug#5":7,"ug#9":4,"ug#7":2,"ug#41":2,"ug#8":2,"ug#36":2,"pg#12":56,"pg#13":55,"pg#14":33,"pg#11":27,"pg#6":7,"pg#3":4,"pg#8":4,"pg#1":4,"pg#10":3,"pg#35":2},"jobType":{"#1":"NoCount","#3":126,"#2":20,"#":2,"#5":1}});
#                 drawCluster(clusterDataObj.genDataForClusters());
#
#         var abc = ims().init({
#             trigger: {selector: '#cjaMain', on: 'click', loader: {auto: '#cjaMain'}/*'#cstLdr'*/},
#             //embedTo : '#emb',
#             url: '/intercept/alert',
#                     postData: 'mod=cja&ftype=show',
#                     requestTimeout: 1E4,
#                     requestSuccess: function(resp) {
#                         console.log('Success')
#                     },
#                     requestFail: function() {
#                         console.log('Failed')
#                     },
#                     crossDomain: true,
#                     autoInvoke: false
#                 });
# </script>
# <script>
#  var rp_belly_url = "https://www.naukri.com/rp-belly-ads";
#       showRPBEllyAds(rp_belly_url ,searchParam["qp"]);
# </script>
# <script src="https://www.google.com/adsense/search/ads.js" type="text/javascript">
# </script>
# <script charset="utf-8" type="text/javascript">
#  var pageOptions = {'pubId': 'pub-9554081520005828','query': 'data scientist jobs ', 'channel': '3284496911,1249360515,2586492913', 'adtest': 'off', 'adpage': '1', 'hl': 'en', 'adsafe': 'high'};
#
#     var adblock_Right = {'container': 'GOOGLEADS_RT', 'number':3, 'colorAdSeparator': '#BBBBBB', 'fontFamily': 'arial', 'fontSizeTitle': '12px', 'fontSizeDescription': '12px', 'colorTitleLink': '#0043CC', 'colorBackground': '#FEFEE4', 'linkTarget': '_blank', 'rightHandAttribution': 'true', 'width': '250px', 'titleBold': true};
#
#     var adblock_Center = {'container': 'GOOGLEADS_CENTER', 'colorBackground': '#FFFFFF', 'number':3, 'titleBold': 'false', 'fontSizeTitle': '13', 'colorTitleLink': '#00F', 'verticalSpacing': 12, 'linkTarget': '_blank', 'noTitleUnderline': 'true', 'colorAdSeparator': '#CBCBCB', 'rightHandAttribution': 'true', 'colorDomainLink': '#04A414'};
#
#     var adblock_Bottom = {'container': 'GOOGLEADS_BOT', 'colorBackground': '#FFFFFF', 'number':3, 'titleBold': 'false', 'fontSizeTitle': '13', 'colorTitleLink': '#00F', 'linkTarget': '_blank', 'verticalSpacing': 12, 'noTitleUnderline': 'true', 'colorAdSeparator': '#CBCBCB', 'rightHandAttribution': 'true', 'colorDomainLink': '#04A414'};
#
#     new google.ads.search.Ads(pageOptions, adblock_Center, adblock_Bottom, adblock_Right);
# </script>
# <script type="text/javascript">
#  var zedoParam = {"pageId":"512464","customParam":"geo:'528462'","naukriId":"1380","banners":[{"bannerId":"zt_512464_1","pageId":"512464","position":1,"channelId":"17","sizeId":"9","flag":"1","width":"300","height":"250"},{"bannerId":"zt_512464_2","pageId":"512464","position":2,"channelId":"17","sizeId":"85","flag":"1","width":"300","height":"250"},{"bannerId":"zt_512464_3","pageId":"512464","position":3,"channelId":"2334","sizeId":"31","flag":"1","width":"970","height":"90"}]}
#                         var nlLeadSubmitUrl = 'https://www.naukri.com/jobsearch/nlsubmitLead';
# </script>
# <script async="" src="https://saxp.zedo.com/sclient/tt3/fmos.js" type="text/javascript">
# </script>
# <script>
#  dataLayer =[];
#
# dataLayer.push({
#
#         'SRP_keyword' : 'data scientist',
#         'SRP_experience' : 'Null',
#         'SRP_location' : 'mumbai',
#         'SRP_category' : 'Null',
#         'SRP_Farea' : 'Null',
#         'SRP_industry' : 'Null',
#         'SRP_Sal_min' : 'Null',
#         'SRP_Sal_max' : 'Null',
#                 'User_LoggedIn' : 'false',
#         'User_Type' : 'nonPrem',
#         'User_CurrLoc' : 'Null',
#         'User_DesiredLoc' : 'Null',
#         'User_KeySkills' : 'Null',
#         'User_Exp' : 'Null',
#         'User_FArea' : 'Null',
#         'User_Sal_current' : 'Null',
#         'User_Sal_currency' : 'Null',
#         'User_PFarea' : 'Null',
#         'User_Edu_UG' : 'Null',
#         'User_Edu_PG' : 'Null',
#         'Visit_SourceID': 'Null',
#         'SRP_JOBIDS' : ['100318003940','030318003636','090318900343','090318001216','090318005810']
# });
# ub.track("srpView", {
#     searchId: searchParam['sid'],
#     keyword: searchParam["qp"],
#     location:searchParam["ql"],
#     experience : searchParam["qe"],
#     salary : searchParam["qm"],
#     latLong :searchParam['latLong'],
#     freshnessCluster : searchParam['qco[]'],
#     salaryCluster : searchParam['qctc[]'],
#     locationCluster:searchParam['qcl[]'],
#     industryCluster:searchParam['qci[]'],
#     eduCluster : searchParam['edu[]'],
#     jobTypeCluster:searchParam['qcjt[]'],
#    username:username,
#    searchCount:342
# });
# </script>
# <script type="text/javascript">
#  var sectionCode = sectionCode || [];
#
#   sectionCode.push("7ce9431b-db59-423e-a0e4-746b1ac09864");
#
#   (function(){
#     var script = document.createElement("script");
#     script.async = true;
#     script.src = "https://s.yimg.com/av/gemini/ga/gemini.js";
#     document.body.appendChild(script);
#   })();
# </script>
# <script type="text/javascript">
#  (function(w, d, s, l, i) {
#        w[l] = w[l] || [];
#        w[l].push({
#            'gtm.start': new Date().getTime(),
#            event: 'gtm.js'
#        });
#        var f = d.getElementsByTagName(s)[0],
#            j = d.createElement(s),
#            dl = l != 'dataLayer' ? '&l=' + l : '';
#        j.async = true;
#        j.src =
#            'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
#        f.parentNode.insertBefore(j, f);
#    })(window, document, 'script', 'dataLayer', 'GTM-NX744H');
# </script>
# <noscript>
#  <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-NX744H" style="display:none;visibility:hidden" width="0">
#  </iframe>
# </noscript>
# <script>
#  var _comscore = _comscore || [];
#   _comscore.push({ c1: "2", c2: "6035313" });
#   (function() {
#     var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#     s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#     el.parentNode.insertBefore(s, el);
#   })();
# </script>
# <noscript>
#  <img src="http://b.scorecardresearch.com/p?c1=2&amp;c2=6035313&amp;cv=2.0&amp;cj=1"/>
# </noscript>

# %%
############# title
title = []
for div in soup.find_all(name="li", attrs={"itemprop":"title"}):
    title.append(div.get_text())
    
############# Company Name
name = []
for div in soup.find_all(name="span", attrs={"itemprop":"hiringOrganization"}):
    name.append(div.get_text())
    
############# Work Experience
exp = []
for div in soup.find_all(name="span", attrs={"itemprop":"experienceRequirements"}):
    exp.append(div.get_text())
    
############ Location
location = []
for div in soup.find_all(name="span", attrs={"itemprop":"jobLocation"}):
    location.append(div.get_text())

############ skills
skills = []
for div in soup.find_all(name="span", attrs={"itemprop":"skills"}):
    skills.append(div.get_text())
    
############ salary
salary = []
for div in soup.find_all(name="span", attrs={"itemprop":"baseSalary"}):
    salary.append(div.get_text())
    
############ Date Posted
dateposted = []
for div in soup.find_all(name="span", attrs={"class":"date"}):
    dateposted.append(div.get_text())
    
############ ApplyLinks
applylinks = []
for link in soup.find_all(name="a", attrs={"target":"_blank", "class":"content"}):
    applylinks.append(str(link.attrs['href'])) 
#print(applylinks)
# Out:
# 50

# %%
for i in range(1,20):
    print(title[i]+","+name[i]+","+ exp[i] +","+location[i]+","+skills[i]+","+salary[i]+","+dateposted[i])
    print("\n")
# Out:
# Principal Data Scientist,HERE Solutions India Private Limited,8-11 yrs,Mumbai,Machine Learning, Deep Learning, Computer Vision, Analytics, Big Data, Data...,  Not disclosed ,3 days ago
#
#
# Data Scientist,Harjai Computers Pvt Ltd,1-3 yrs,Mumbai,Data Science, Machine Learning, R, Python,  Not disclosed ,1 day ago
#
#
# Data Scientist,Truebil.com,2-5 yrs,Mumbai,SAS, Excel, R, SQL, Analytics Reporting, Statistical Modeling...,  Not disclosed ,2 days ago
#
#
# Looking for Data Scientist,Tech Mahindra Ltd.,5-9 yrs,Mumbai,Data Science,    7,00,000 - 12,00,000 P.A.  ,2 days ago
#
#
# Data Scientist,Exponentia Datalabs,3-8 yrs,Mumbai,deep learning, text mining, hadoop, hive, r, data analysis, nlp, sql, spark...,  Not disclosed ,2 days ago
#
#
# Data Scientist,PiSight - Startup,2-5 yrs,Mumbai,Hadoop, Hive, NoSQL, HBase, Spark, Pig, Cassandra, SQL, MongoDB, Hibernate,...,  Not disclosed ,4 days ago
#
#
# Data Scientist / Machine Learning Engineer - Python,SmartConnect Technologies,3-5 yrs,Mumbai,Python, Data Scientist, Machine Learning, Data analysis, Data Analytics...,  Not disclosed ,59 days ago
#
#
# Data Scientists,Client Of Sampoorna,5-7 yrs,Mumbai,Data Scientist, data analysis, data mining, statistics, machine learning...,  Not disclosed ,5 days ago
#
#
# Senior Data Scientist,Cactus Communications Pvt. Ltd.,2-7 yrs,Mumbai,MySQL, PHP, Laravel, Drupal, Angularjs, Solr, MongoDB, Postgresql, Python...,    15,00,000 - 20,00,000 P.A.  ,16 days ago
#
#
# DATA Scientist,Personnel Search Services Pvt Ltd,4-7 yrs,Mumbai,quantitative analytics or data modeling, Python, C, C++, Java, SQL,  Not disclosed ,5 days ago
#
#
# Trainee - Data Scientist/ USA Australia,MNC,0-1 yrs,Mumbai, Bengaluru, Pune,Data Scientist,    12,00,000 - 22,00,000 P.A.  ,5 days ago
#
#
# Trainee - Data Scientist/ USA Australia,MNC,0-1 yrs,Mumbai, Pune,Data Scientist,    12,00,000 - 22,00,000 P.A.  ,5 days ago
#
#
# Data Scientist (machine Learning, NLP & Python Development Engineer),Premium,3-8 yrs,Thane, Mumbai,Deep Learning, Text Mining, Machine Learning, NLP, R, Data Mining...,  Not disclosed ,23 days ago
#
#
# Data Analyst, Data Scientist,Confidential,0-3 yrs,Mumbai,C, C++, Image Processing, Opencv, Computer Vision, Machine Learning, Cuda...,  Not disclosed ,10 days ago
#
#
# Senior Data Scientist,JPMorgan Chase,3-5 yrs,Mumbai,data science, Algorithms, Service, Consulting, Data analysis, Auditing...,  Not disclosed ,25 days ago
#
#
# Senior Data Scientist,Upstox - Startup,5-10 yrs,Mumbai,data science, r, python, statistics, data scientist, Data Analyst,  Not disclosed ,25 days ago
#
#
# Senior Data Scientist,JP Morgan Chase,0-5 yrs,Mumbai, Mumbai,technology, finance, operations, human resources,  Not disclosed ,27 days ago
#
#
# Python Data Scientist - Analyst/ Sr Analyst,OST Placement Search Private Limited,2-6 yrs,Delhi NCR, Bengaluru, Mumbai,Analytical Techniques,    10,00,000 - 20,00,000 P.A.  ,30 days ago
#
#
# Lead Data Scientist - Education Technology Firm,Premium,8-10 yrs,Mumbai,machine learning, neural networks, r, data science, algorithms, sas...,  Not disclosed ,10 days ago

# %%
from pandas import DataFrame
df = DataFrame({'Job title': title, 'Company Name': name, 'Work Experience': exp, 'Job Location': location, 'skills': skills, 'salary': salary, 'dateposted': dateposted})
df
# Out:
#                                        Company Name  \
# 0                         Crescendo Global Services
# 1              HERE Solutions India Private Limited
# 2                          Harjai Computers Pvt Ltd
# 3                                       Truebil.com
# 4                                Tech Mahindra Ltd.
# 5                               Exponentia Datalabs
# 6                                 PiSight - Startup
# 7                         SmartConnect Technologies
# 8                               Client Of Sampoorna
# 9                   Cactus Communications Pvt. Ltd.
# 10                Personnel Search Services Pvt Ltd
# 11                                              MNC
# 12                                              MNC
# 13                                          Premium
# 14                                     Confidential
# 15                                   JPMorgan Chase
# 16                                 Upstox - Startup
# 17                                  JP Morgan Chase
# 18             OST Placement Search Private Limited
# 19                                          Premium
# 20                        Crescendo Global Services
# 21                      Diligence Netsoft pvt. ltd.
# 22                                Atria BioSciences
# 23                                          Premium
# 24         UBS Business Solutions (India) Pvt. Ltd.
# 25                                         NanoNets
# 26                                         NanoNets
# 27                                     Confidential
# 28                                       Job Finder
# 29                             Rock Solid Solutions
# 30                                          Premium
# 31                                          Premium
# 32            TransOrg Solutions  Services (P) Ltd.
# 33                                   ICICI Bank Ltd
# 34                              Exponentia Datalabs
# 35                                 PiSight- Startup
# 36                                Startup - Stylabs
# 37                             Vahanalytics-Startup
# 38                                          Premium
# 39               Think People Solutions Private Ltd
# 40                                      Truebil.com
# 41                       Morningstar India (P) Ltd.
# 42                                10XDigitalPro.com
# 43                       Smart Connect Technologies
# 44         HDFC Standard Life Insurance Company Ltd
# 45                               TransOrg Analytics
# 46  Chenoa Information  Software Services Pvt. Ltd.
# 47                               TransOrg Analytics
# 48                                 Paysense-Startup
# 49                       Hindustan Unilever Limited
#
#                                          Job Location  \
# 0                                              Mumbai
# 1                                              Mumbai
# 2                                              Mumbai
# 3                                              Mumbai
# 4                                              Mumbai
# 5                                              Mumbai
# 6                                              Mumbai
# 7                                              Mumbai
# 8                                              Mumbai
# 9                                              Mumbai
# 10                                             Mumbai
# 11                            Mumbai, Bengaluru, Pune
# 12                                       Mumbai, Pune
# 13                                      Thane, Mumbai
# 14                                             Mumbai
# 15                                             Mumbai
# 16                                             Mumbai
# 17                                     Mumbai, Mumbai
# 18                       Delhi NCR, Bengaluru, Mumbai
# 19                                             Mumbai
# 20                                             Mumbai
# 21  Delhi NCR, Mumbai, Bengaluru, Chennai, Hyderab...
# 22  Delhi NCR, Mumbai, Bengaluru, Chennai, Hyderab...
# 23                                             Mumbai
# 24                                        Navi Mumbai
# 25                                             Mumbai
# 26                                             Mumbai
# 27                                             Mumbai
# 28                                             Mumbai
# 29                                             Mumbai
# 30                                             Mumbai
# 31                                             Mumbai
# 32                                             Mumbai
# 33                Mumbai, Mumbai Suburbs, Navi Mumbai
# 34                                             Mumbai
# 35                                             Mumbai
# 36                                             Mumbai
# 37                                             Mumbai
# 38                                             Mumbai
# 39                                             Mumbai
# 40                                             Mumbai
# 41                                Mumbai, Navi Mumbai
# 42                                             Mumbai
# 43                                        Navi Mumbai
# 44                                             Mumbai
# 45                                             Mumbai
# 46                                             Mumbai
# 47                                             Mumbai
# 48                                             Mumbai
# 49                                    Mumbai(Chakala)
#
#                                             Job title Work Experience  \
# 0   Am/dm/manager Data Scientist Insurance (2-8 Ye...         2-7 yrs
# 1                            Principal Data Scientist        8-11 yrs
# 2                                      Data Scientist         1-3 yrs
# 3                                      Data Scientist         2-5 yrs
# 4                          Looking for Data Scientist         5-9 yrs
# 5                                      Data Scientist         3-8 yrs
# 6                                      Data Scientist         2-5 yrs
# 7   Data Scientist / Machine Learning Engineer - P...         3-5 yrs
# 8                                     Data Scientists         5-7 yrs
# 9                               Senior Data Scientist         2-7 yrs
# 10                                     DATA Scientist         4-7 yrs
# 11            Trainee - Data Scientist/ USA Australia         0-1 yrs
# 12            Trainee - Data Scientist/ USA Australia         0-1 yrs
# 13  Data Scientist (machine Learning, NLP & Python...         3-8 yrs
# 14                       Data Analyst, Data Scientist         0-3 yrs
# 15                              Senior Data Scientist         3-5 yrs
# 16                              Senior Data Scientist        5-10 yrs
# 17                              Senior Data Scientist         0-5 yrs
# 18        Python Data Scientist - Analyst/ Sr Analyst         2-6 yrs
# 19    Lead Data Scientist - Education Technology Firm        8-10 yrs
# 20     Data Scientist-machine Learning/ Deep Learning        5-10 yrs
# 21  Software Engineer - Machine Learning, Pyhton/r...         2-7 yrs
# 22                      DATA Scientist / R Programmer         0-2 yrs
# 23                               Chief Data Scientist       15-20 yrs
# 24                                     Data Scientist         3-6 yrs
# 25    Deep Learning Engineer ( Senior Data Scientist)        5-10 yrs
# 26                            Founding Data Scientist         2-5 yrs
# 27                     Data Scientist - Deep Learning         3-5 yrs
# 28               Data Miner/data Scientist- R & Arima         3-7 yrs
# 29  Data Scientist / Analyst / Machine Learning En...         2-5 yrs
# 30  Data Scientist (machine Learning, NLP & Python...         4-9 yrs
# 31   Data Scientist/analyst - Artificial Intelligence         2-5 yrs
# 32   Data Scientist - R/python & Predictive Modelling         2-6 yrs
# 33                                     Data Scientist       13-17 yrs
# 34  Onsite(uk) Job Opportunity for Sr. Data Scientist         3-8 yrs
# 35                                     Data Scientist         3-5 yrs
# 36                                     Data Scientist         2-5 yrs
# 37                              Senior Data Scientist         2-5 yrs
# 38                          Lead Data Scientist - KPO        8-13 yrs
# 39  Hiring for Sr. Data Scientist with Leading IT ...         4-8 yrs
# 40                                     Data Scientist         2-5 yrs
# 41                                     Data Scientist         2-7 yrs
# 42                    Data Scientist - Logistics Firm        5-10 yrs
# 43                                     Data Scientist         3-5 yrs
# 44               Data Scientist - Marketing Analytics         3-8 yrs
# 45                               Data Scientist - SAS         2-6 yrs
# 46  Urgently Looking for Data Scientist (nlp-manda...         3-8 yrs
# 47                               Data Scientist - SAS         2-6 yrs
# 48                              Senior Data Scientist         2-7 yrs
# 49  Data Scientist, People Data Centre - Hindustan...        5-10 yrs
#
#      dateposted                                         salary  \
# 0     1 day ago                    7,00,000 - 14,00,000 P.A.
# 1    3 days ago                                 Not disclosed
# 2     1 day ago                                 Not disclosed
# 3    2 days ago                                 Not disclosed
# 4    2 days ago                    7,00,000 - 12,00,000 P.A.
# 5    2 days ago                                 Not disclosed
# 6    4 days ago                                 Not disclosed
# 7   59 days ago                                 Not disclosed
# 8    5 days ago                                 Not disclosed
# 9   16 days ago                   15,00,000 - 20,00,000 P.A.
# 10   5 days ago                                 Not disclosed
# 11   5 days ago                   12,00,000 - 22,00,000 P.A.
# 12   5 days ago                   12,00,000 - 22,00,000 P.A.
# 13  23 days ago                                 Not disclosed
# 14  10 days ago                                 Not disclosed
# 15  25 days ago                                 Not disclosed
# 16  25 days ago                                 Not disclosed
# 17  27 days ago                                 Not disclosed
# 18  30 days ago                   10,00,000 - 20,00,000 P.A.
# 19  10 days ago                                 Not disclosed
# 20  33 days ago                   25,00,000 - 30,00,000 P.A.
# 21  60 days ago                                 Not disclosed
# 22  20 days ago                     3,00,000 - 4,75,000 P.A.
# 23   2 days ago                                 Not disclosed
# 24   2 days ago                                 Not disclosed
# 25   3 days ago                                 Not disclosed
# 26   3 days ago                                 Not disclosed
# 27   5 days ago                                 Not disclosed
# 28   5 days ago      6,00,000 - 9,00,000 P.A. General Shifts
# 29  16 days ago                                 Not disclosed
# 30  27 days ago                                 Not disclosed
# 31  59 days ago                                 Not disclosed
# 32  13 days ago                                 Not disclosed
# 33  23 days ago                                 Not disclosed
# 34  27 days ago                                 Not disclosed
# 35  30 days ago                                 Not disclosed
# 36  23 days ago                                 Not disclosed
# 37  26 days ago                                 Not disclosed
# 38  12 days ago                                 Not disclosed
# 39  13 days ago                    5,00,000 - 15,00,000 P.A.
# 40  52 days ago                                 Not disclosed
# 41  54 days ago                    5,00,000 - 12,00,000 P.A.
# 42  58 days ago                                 Not disclosed
# 43  59 days ago                                 Not disclosed
# 44  55 days ago                                 Not disclosed
# 45  33 days ago                                 Not disclosed
# 46  32 days ago                                 Not disclosed
# 47  61 days ago                                 Not disclosed
# 48  48 days ago                                 Not disclosed
# 49  33 days ago                                 Not disclosed
#
#                                                skills
# 0   Deep Learning, Text Mining, Natural Language P...
# 1   Machine Learning, Deep Learning, Computer Visi...
# 2           Data Science, Machine Learning, R, Python
# 3   SAS, Excel, R, SQL, Analytics Reporting, Stati...
# 4                                        Data Science
# 5   deep learning, text mining, hadoop, hive, r, d...
# 6   Hadoop, Hive, NoSQL, HBase, Spark, Pig, Cassan...
# 7   Python, Data Scientist, Machine Learning, Data...
# 8   Data Scientist, data analysis, data mining, st...
# 9   MySQL, PHP, Laravel, Drupal, Angularjs, Solr, ...
# 10  quantitative analytics or data modeling, Pytho...
# 11                                     Data Scientist
# 12                                     Data Scientist
# 13  Deep Learning, Text Mining, Machine Learning, ...
# 14  C, C++, Image Processing, Opencv, Computer Vis...
# 15  data science, Algorithms, Service, Consulting,...
# 16  data science, r, python, statistics, data scie...
# 17   technology, finance, operations, human resources
# 18                              Analytical Techniques
# 19  machine learning, neural networks, r, data sci...
# 20  Hive, Spark, Hadoop, Pig, Deep Learning, SCALA...
# 21  Data Science, R, Machine Learning, Python, Log...
# 22  clinical data, spss, Python, R, SAS, Tableau, ...
# 23  Data Scientist, Data Science, Deep Learning An...
# 24  data scientist, data science, analytics, table...
# 25  Deep Learning Engineer, Data Scientist, Deep L...
# 26  Data Scientist, Data Science, Tensorflow, Mach...
# 27  Deep Learning, TensorFlow, Yolo, SSD, Faster -...
# 28  Arima, R, R programming, Data scientist, data ...
# 29  python, spark, machine learning, scikit learn,...
# 30  Deep Learning, Text Mining, Machine Learning, ...
# 31  Deep Learning, Natural Language Processing, Te...
# 32  R, Predictive Modeling, Logistic Regression, P...
# 33  Discoverer, Big Data, Product Development, Dat...
# 34  deep learning, natural language processing, ne...
# 35  Data Scientist, Agile Scrum process, Hibernate...
# 36  Natural Language Processing, Text Mining, Mach...
# 37                          Big Data, Data Collection
# 38  Data Scientist, Regression, neural networks, m...
# 39  Machine Learning, Python, R, Finance, Business...
# 40  Data Scientist, data mining, business process ...
# 41  python, r, sql, analytics, machine learning, d...
# 42  r, machine learning, python, predictive modeli...
# 43  Data Scientist, Machine Learning, Natural Lang...
# 44                          sas, Analytics, Marketing
# 45  sas, r, predictive modeling, logistic regressi...
# 46  nlp, data science, r, predictive analytics, ma...
# 47  sas, r, predictive modeling, logistic regressi...
# 48  Python, Django, Data Science, Machine Learning...
# 49  Machine Learning, Natural Language Processing,...

# %%
applylinks = []
for link in soup.find_all(name="a", attrs={"target":"_blank", "class":"content"}):
    applylinks.append(str(link.attrs['href'])) 
print(applylinks)
# Out:
# ['https://www.naukri.com/job-listings-Am-dm-manager-Data-Scientist-Insurance-2-8-Years-Crescendo-Global-Services-Mumbai-2-to-7-years-100318003940?src=jobsearchDesk&sid=15207450423413&xp=1&px=1']
# 1
