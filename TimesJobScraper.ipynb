# %%
########################## times job

import requests
import bs4
from bs4 import BeautifulSoup
import pandas as pd
import time

URL = "http://www.timesjobs.com/jobs-in-mumbai/android-developer-jobs"
#conducting a request of the stated URL above:
page = requests.get(URL)
#specifying a desired format of “page” using the html parser - this allows python to read the various components of the page, rather than treating it as one long string.
soup = BeautifulSoup(page.text, "html.parser")
#printing soup in a more structured tree format that makes for easier reading
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    Access Denied
#   </title>
#  </head>
#  <body>
#   <h1>
#    Access Denied
#   </h1>
#   You don't have permission to access "http://www.quikr.com/jobs/full-time+it-software-web-designer+mumbai+zwqxj1452070842" on this server.
#   <p>
#    Reference #18.ec70903b.1520713012.1743fc5d
#   </p>
#  </body>
# </html>

# %%
for div in soup.find_all(name="span", attrs={"class":"srp-skills"}):
    print(div.get_text())
# Out:
# android
# ios
# dalvik
# ul
#
#
# Android developer
# CSS
# H
# Android
#
#
# Analytical
# Competitive
# Android
#
#
# Android Application Developer
# ObjectiveC
# analytical skills
#
#
# Android Developement
# knowledge of OOP
# design patterns
# Android architecture
#
#
# Python and data analysis
# comfortable in building Android apps
# unit testing
# understand REST api's
# Java
# SQL
# Android
# Algorithms
# JSON
# Google Maps API
#
#
# Java
# back-end services
# native android applications
# maintenance of applications
# product development
# RESTful Services
# JSON
#
#
# JQuery Mobile
# internals and strong Java
# XML
# JSON
# Android SDK
# UX outputs
#
#
# quality
# Java code
# code versioning tools
# Googles Android design principles
# software engineering
# continuous integration
#
#
# Eclipse
# Android Studio
# Web Services
# JSON
# XML
# programming and debugging skills
# design and development
#
#
# core java
# Maven
# Android Framework Knowledge
# ...

# %%
for div in soup.find_all(name="h3", attrs={"class":"joblist-comp-name"}):
    print(div.get_text())
# Out:
# Sunline Greensystems Pvt Ltd
# (More Jobs)
#
#
#
# INDIA PLACEMENT
# (More Jobs)
#
#
#
# Quorg Technologies
# (More Jobs)
#
#
#
# TRIANGLE REDEFINE PEOPLE SEARCH
#
#
# BicneT Infoservices Private Limited
#
#
# Easy Roads
#
#
# RASA MARKETING
#
#
# Bee5 Manpower Consulting
#
#
# flochat
#
#
# Website Developers India
#
#
# AMBIENCE MANAGEMENT SERVICES
#
#
# CP CAREERS PRIVATE LIMITED
#
#
# Jobtrack Management Services Pvt. Ltd
#
#
# Sofomation
#
#
# SOFOMATION
#
#
# Entrepreneurs Institute
#
#
# Ideamagix
#
#
# SQUAD INFOTECH PRIVATE LTD
#
#
# TRIANGLE Redefine People Search
#
#
# Driefcase Healthtech Pvt. Ltd.
#
#
# IDfy
#
#
# SQUAD Infotech Pvt. Ltd.
#
#
# Health Care ( Stealth Mode )
#
#
# Websites.co.in
#
#
# Codetreasure
#
#
# UKS TECHNOLOGIES PVT. LTD.
#
#
# Sharad Technologies LLC
#
#
# Tickled Media
#
#
# Unistanz Software Private Limited
#
#
# Flochat
#
#
# Innovizia Technologies
#
#
# JUSTRIDE.in
#
#
# YumLane
#
#
# Upstox
#
#
# Bluehorse Software
#
#
# Insider
#
#
# ...

# %%
for div in soup.find_all(name="span", attrs={"class":"icon exp"}):
    print(div.get_text())
